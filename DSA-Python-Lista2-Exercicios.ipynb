# %% [markdown]
# <!-- Trabalho Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Fundamentos de Linguagem Python - Do Básico a Aplicações de IA</font>
# # <font color='blue'>Lista 2 de Exercícios</font>

# %% [markdown]
# #### Exercício 1
#
# Escreva uma função que receba os valores de três lados de um triângulo e o classifique como "Equilátero" (todos os lados iguais), "Isósceles" (dois lados iguais) ou "Escaleno" (todos os lados diferentes).

# %%
# Solução
lado_a=float(input("\nDigite o tamanho do lado 'a' do triângulo: "))
lado_b=float(input("Digite o tamanho do lado 'b' do triângulo: "))
lado_c=float(input("Digite o tamanho do lado 'c' do triângulo: "))

def side_triangule(a,b,c):
    if a==b==c:
        print("\nTriângulo Equilátero (todos os lados iguais)")
    elif (a==b and a!=c and b!=c) or (a==c and a!=b and b!=c) or (b==c and a!=b and a!=c):
        print("\nTriângulo Isósceles (dois lados iguais)")
    else:
        print ("\nTriângulo Escaleno (todos os lados diferentes)")
        
side_triangule(lado_a,lado_b,lado_c)
# Out:
# Digite o tamanho do lado 'a' do triângulo:  2
# Digite o tamanho do lado 'b' do triângulo:  2
# Digite o tamanho do lado 'c' do triângulo:  3
# Triângulo Isósceles (dois lados iguais)

# %% [markdown]
# #### Exercício 2
#
# Escreva uma função que recebe um número inteiro e exibe a tabuada de multiplicação desse número, do 1 ao 10.

# %%
# Solução
numero=int(input("Resolver a tabuada do número "))

def tabuada(x):
    for i in range(1,11):
        print(f"{numero} x {i} = {numero * i}")

tabuada(numero)
# Out:
# Resolver a tabuada do número  3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# #### Exercício 3
#
# Você recebeu um dicionário com os nomes dos alunos e suas respectivas notas. Escreva uma função que calcula a média da turma e retorna uma lista com os nomes dos alunos que tiveram nota acima da média.

# %%
# Solução
alunos = {
    "Ana Souza": 8.5,
    "Bruno Lima": 7.0,
    "Carla Mendes": 9.2,
    "Daniel Oliveira": 6.8,
    "Eduarda Santos": 7.5,
    "Felipe Costa": 8.0,
    "Gabriela Rocha": 5.9,
    "Henrique Almeida": 9.5,
    "Isabela Ferreira": 6.3,
    "João Pereira": 7.8,
    "Larissa Martins": 8.9,
    "Lucas Rodrigues": 4.7,
    "Mariana Barbosa": 6.5,
    "Matheus Ribeiro": 7.3,
    "Natália Gomes": 8.1,
    "Pedro Carvalho": 5.4,
    "Rafaela Dias": 9.0,
    "Ricardo Nunes": 6.9,
    "Sofia Teixeira": 7.6,
    "Thiago Azevedo": 8.3
}

def media(dicionario):

    mean= sum(dicionario.values())/len(dicionario)
    print(f"\nMédia da turma: {mean:.2f}")

    print("\nAlunos acima da média:")

    for nome, nota in dicionario.items():
        if nota > mean:
            print(f"{nome}")
    
media(alunos)
# Out:
# Média da turma: 7.46
#
# Alunos acima da média:
# Ana Souza
# Carla Mendes
# Eduarda Santos
# Felipe Costa
# Henrique Almeida
# João Pereira
# Larissa Martins
# Natália Gomes
# Rafaela Dias
# Sofia Teixeira
# Thiago Azevedo

# %% [markdown]
# #### Exercício 4
#
# Dada uma lista de números, crie uma nova lista usando list comprehension que contenha o quadrado de cada número par da lista original.

# %%
# Solução
import random

numeros = [random.randint(0, 10) for _ in range(10)]
print("Lista:", numeros)

# Primeiro calculamos os quadrados com map + lambda
quadrados = list(map(lambda x: x ** 2, numeros))

# Agora filtramos apenas os pares com filter + lambda
quadrados_pares = list(filter(lambda x: x % 2 == 0, quadrados))

print("Quadrados:", quadrados)
print("Quadrados pares:", quadrados_pares)
# Out:
# Lista: [3, 9, 5, 8, 0, 9, 7, 5, 1, 6]
# Quadrados: [9, 81, 25, 64, 0, 81, 49, 25, 1, 36]
# Quadrados pares: [64, 0, 36]

# %% [markdown]
# #### Exercício 5
#
# Crie uma função chamada dsa_calcula_imc que aceite dois argumentos: peso (em kg) e altura (em metros). A função deve calcular o Índice de Massa Corporal (IMC) usando a fórmula IMC=peso/altura^2 e retornar o valor do IMC.

# %%
# Solução
alt=float(input("Digite sua altura (em metros): "))
weight=float(input("Digite seu peso (em kg): "))

def dsa_calcula_imc(altura,peso):
    imc=peso/(altura**2)
    print(f"Índice de Massa Corporal (IMC): {imc: .2f}.")

dsa_calcula_imc(altura=alt,peso=weight)
# Out:
# Digite sua altura (em metros):  1.84243
# Digite seu peso (em kg):  92.325
# Índice de Massa Corporal (IMC):  27.20.

# %% [markdown]
# #### Exercício 6
#
# Você tem uma lista de dicionários, onde cada dicionário representa uma pessoa com nome e idade. Use a função sorted() com uma expressão lambda como chave (key) para ordenar a lista de pessoas da mais nova para a mais velha.

# %%
# Solução
pessoas = [
    {"nome": "Ana", "idade": 25},
    {"nome": "Bruno", "idade": 30},
    {"nome": "Carla", "idade": 22},
    {"nome": "Daniel", "idade": 28},
    {"nome": "Eduarda", "idade": 35},
    {"nome": "Felipe", "idade": 27},
    {"nome": "Gabriela", "idade": 24},
    {"nome": "Henrique", "idade": 32},
    {"nome": "Isabela", "idade": 29},
    {"nome": "João", "idade": 26}
]

ordem= sorted(pessoas, key=lambda pessoa: pessoa["idade"])

for pessoa in ordem:
    print(f"{pessoa["nome"]}: {pessoa["idade"]} anos")
# Out:
# Carla: 22 anos
# Gabriela: 24 anos
# Ana: 25 anos
# João: 26 anos
# Felipe: 27 anos
# Daniel: 28 anos
# Isabela: 29 anos
# Bruno: 30 anos
# Henrique: 32 anos
# Eduarda: 35 anos

# %% [markdown]
# #### Exercício 7
#
# Crie uma função que receba uma lista de números inteiros e retorne um dicionário contendo a contagem de quantos números são pares e quantos são ímpares.

# %%
# Solução
import random

numeros = [random.randint(0, 10) for _ in range(10)]
print("Lista:", numeros)

def exibe_par_impar(lista):
    contagem = {"pares": 0, "impares": 0}
    
    for numero in lista:
        if numero % 2 == 0:
            contagem["pares"] += 1
        else:
            contagem["impares"] += 1          
    return contagem
    
print(f"Contagem: {exibe_par_impar(numeros)}")
# Out:
# Lista: [7, 3, 1, 1, 2, 5, 2, 10, 1, 1]
# Contagem: {'pares': 3, 'impares': 7}

# %% [markdown]
# #### Exercício 8
#
# Crie uma função que receba uma lista de strings (potenciais e-mails) e um parâmetro opcional dominio_desejado (com valor padrão "gmail.com"). A função deve retornar uma nova lista, usando list comprehension, contendo apenas os e-mails que terminam com o domínio desejado.

# %%
# Solução
emails = [
    "ana@gmail.com",
    "bruno@yahoo.com",
    "carla@gmail.com",
    "daniel@outlook.com",
    "eduarda@gmail.com",
    "email_invalido",
    "felipe@usp.br"
]

gmail = list(filter(lambda email:email.endswith("@" + "gmail.com"), emails))

print("\nE-mails do domínio 'gmail.com': ", gmail)
# Out:
# E-mails do domínio 'gmail.com':  ['ana@gmail.com', 'carla@gmail.com', 'eduarda@gmail.com']

# %% [markdown]
# #### Exercício 9
#
# Dada uma lista de frases, use a função map() em conjunto com uma expressão lambda para criar uma nova lista onde cada frase é convertida para letras maiúsculas e tem a palavra "PYTHON" anexada ao final.

# %%
# Solução
frases = [
    "Python é uma linguagem poderosa e versátil.",
    "A prática constante melhora a lógica de programação.",
    "List comprehension deixa o código mais elegante.",
    "Erros fazem parte do processo de aprendizagem.",
    "Funções ajudam a organizar melhor o código.",
    "Persistência é essencial para evoluir na programação.",
    "Organização torna projetos mais eficientes.",
    "Aprender a debugar é tão importante quanto programar.",
    "Pequenos avanços diários geram grandes resultados.",
    "Entender o problema é metade da solução."
]

novas_frases = list(map(lambda frase: frase.upper() and frase.replace(".","") + " PYTHON.", frases))

print(novas_frases)
# Out:
# ['Python é uma linguagem poderosa e versátil PYTHON.', 'A prática constante melhora a lógica de programação PYTHON.', 'List comprehension deixa o código mais elegante PYTHON.', 'Erros fazem parte do processo de aprendizagem PYTHON.', 'Funções ajudam a organizar melhor o código PYTHON.', 'Persistência é essencial para evoluir na programação PYTHON.', 'Organização torna projetos mais eficientes PYTHON.', 'Aprender a debugar é tão importante quanto programar PYTHON.', 'Pequenos avanços diários geram grandes resultados PYTHON.', 'Entender o problema é metade da solução PYTHON.']

# %% [markdown]
# #### Exercício 10
#
# Crie um jogo onde o computador escolhe um número secreto entre 1 e 20. O jogador tem 5 tentativas para adivinhar. A cada tentativa, o programa informa se o palpite foi muito alto ou muito baixo. Se o jogador acertar, o loop deve ser interrompido com uma mensagem de vitória.

# %%
# Solução
import random

list=range(0,21)
print
segredo = random.randint(1, 21)

tentativa=0
while tentativa <= 5:
    tt=int(input("\nEscolha um número inteiro entre 1 e 20: "))
    if tt > segredo:
           print("Muito alto")
    elif tt < segredo:
        print("Muito baixo")
    else:
        print("\nParabéns! Você acertou.")
        break
    tentativa+=1

if tt!= segredo:
    print(f"\nQue pena! Você não encontrou o número {segredo}. Boa sorte na próxima.")
# Out:
# Escolha um número inteiro entre 1 e 20:  7
# Muito alto
# Escolha um número inteiro entre 1 e 20:  3
# Muito baixo
# Escolha um número inteiro entre 1 e 20:  5
# Muito alto
# Escolha um número inteiro entre 1 e 20:  4
# Parabéns! Você acertou.

# %% [markdown]
# # Fim
